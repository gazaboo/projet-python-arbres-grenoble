# %% [markdown]
# # Itération 3: Pandas

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %% [markdown]
# ## Importer les données

# %%
datapath=Path.cwd().parent.parent / "Cours_Python_it3"
datafile = datapath / "ESP_PUBLIC.IDENTITE_ARBRE.csv"
df_arbres = pd.read_csv(datafile)

# %% [markdown]
# ## Iteration 1: Questions

# %%
# La 'fin' des données
df_arbres.tail(2) #bottom_values
# Out:
#        ELEM_POINT_ID      CODE       NOM GENRE  GENRE_DESC CATEGORIE  \
# 31890          24296  ESP14848  ESP14848   VEG  VEGETATION     ESP01
# 31891          24289  ESP14846  ESP14846   VEG  VEGETATION     ESP01
#
#       CATEGORIE_DESC SOUS_CATEGORIE      SOUS_CATEGORIE_DESC CODE_PARENT  ...  \
# 31890          Arbre         ESP174  Arbre d'espaces ouverts      ESP989  ...
# 31891          Arbre         ESP174  Arbre d'espaces ouverts      ESP989  ...
#
#       COURRIER  IDENTIFIANTPLU TYPEIMPLANTATIONPLU INTITULEPROTECTIONPLU  \
# 31890      NaN             NaN                 NaN                   NaN
# 31891      NaN             NaN                 NaN                   NaN
#
#       ANNEEABATTAGE ESSOUCHEMENT DIAMETREARBRE  CAUSEABATTAGE  \
# 31890           NaN          NaN           NaN            NaN
# 31891           NaN          NaN           NaN            NaN
#
#             COLLECTIVITE                                            GeoJSON
# ...

# %%
# Le 'début' des données
df_arbres.head(2)
# Out:
#    ELEM_POINT_ID      CODE       NOM GENRE  GENRE_DESC CATEGORIE  \
# 0          16750  ESP19318  ESP19318   VEG  VEGETATION     ESP01
# 1          20142  ESP18095  ESP18095   VEG  VEGETATION     ESP01
#
#   CATEGORIE_DESC SOUS_CATEGORIE      SOUS_CATEGORIE_DESC CODE_PARENT  ...  \
# 0          Arbre         ESP174  Arbre d'espaces ouverts      ESP995  ...
# 1          Arbre         ESP174  Arbre d'espaces ouverts      ESP995  ...
#
#   COURRIER  IDENTIFIANTPLU TYPEIMPLANTATIONPLU INTITULEPROTECTIONPLU  \
# 0      NaN             NaN                 NaN                   NaN
# 1      NaN             NaN                 NaN                   NaN
#
#   ANNEEABATTAGE ESSOUCHEMENT DIAMETREARBRE  CAUSEABATTAGE       COLLECTIVITE  \
# 0           NaN          NaN           NaN            NaN  Ville de Grenoble
# 1           NaN          NaN           NaN            NaN  Ville de Grenoble
#
#                                              GeoJSON
# ...

# %%
# Recuperer une colonne de mon dataframe
df_annee = df_arbres['ANNEEDEPLANTATION']
df_annee.dropna().to_numpy()
# Out:
# array([1975., 1975., 2001., ..., 1980., 1980., 2005.])

# %%
# Quelles colonnes dans mon dataframe ?
df_arbres.columns.tolist()
# Out:
# ['ELEM_POINT_ID',
#  'CODE',
#  'NOM',
#  'GENRE',
#  'GENRE_DESC',
#  'CATEGORIE',
#  'CATEGORIE_DESC',
#  'SOUS_CATEGORIE',
#  'SOUS_CATEGORIE_DESC',
#  'CODE_PARENT',
#  'CODE_PARENT_DESC',
#  'ADR_SECTEUR',
#  'BIEN_REFERENCE',
#  'GENRE_BOTA',
#  'ESPECE',
#  'VARIETE',
#  'STADEDEDEVELOPPEMENT',
#  'EQUIPE',
#  'REMARQUES',
#  'ANNEEDEPLANTATION',
#  'RAISONDEPLANTATION',
#  'TRAITEMENTCHENILLES',
#  'COURRIER',
#  'IDENTIFIANTPLU',
#  'TYPEIMPLANTATIONPLU',
#  'INTITULEPROTECTIONPLU',
#  'ANNEEABATTAGE',
#  'ESSOUCHEMENT',
#  'DIAMETREARBRE',
#  'CAUSEABATTAGE',
#  'COLLECTIVITE',
#  'GeoJSON']

# %%
# Nombre de lignes dans mon dataframe
nbre_lignes = df_arbres.shape[0]
nbre_lignes
# Out:
# 31892

# %%
df_arbres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31892 entries, 0 to 31891
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ELEM_POINT_ID          31892 non-null  int64
#  1   CODE                   31892 non-null  object
#  2   NOM                    31892 non-null  object
#  3   GENRE                  31892 non-null  object
#  4   GENRE_DESC             31892 non-null  object
#  5   CATEGORIE              31892 non-null  object
#  6   CATEGORIE_DESC         31892 non-null  object
#  7   SOUS_CATEGORIE         31892 non-null  object
#  8   SOUS_CATEGORIE_DESC    31892 non-null  object
#  9   CODE_PARENT            31892 non-null  object
#  10  CODE_PARENT_DESC       31892 non-null  object
#  11  ADR_SECTEUR            31892 non-null  int64
#  12  BIEN_REFERENCE         31892 non-null  object
#  13  GENRE_BOTA             31454 non-null  object
# ...

# %%
df_arbres
# Out:
#        ELEM_POINT_ID      CODE       NOM GENRE  GENRE_DESC CATEGORIE  \
# 0              16750  ESP19318  ESP19318   VEG  VEGETATION     ESP01
# 1              20142  ESP18095  ESP18095   VEG  VEGETATION     ESP01
# 2              23843  ESP17861  ESP17861   VEG  VEGETATION     ESP01
# 3              23841  ESP17860  ESP17860   VEG  VEGETATION     ESP01
# 4               1778  ESP16403  ESP16403   VEG  VEGETATION     ESP01
# ...              ...       ...       ...   ...         ...       ...
# 31887          16922  ESP19587  ESP19587   VEG  VEGETATION     ESP01
# 31888          12659  ESP19291  ESP19291   VEG  VEGETATION     ESP01
# 31889           1869  ESP16427  ESP16427   VEG  VEGETATION     ESP01
# 31890          24296  ESP14848  ESP14848   VEG  VEGETATION     ESP01
# 31891          24289  ESP14846  ESP14846   VEG  VEGETATION     ESP01
#
#       CATEGORIE_DESC SOUS_CATEGORIE      SOUS_CATEGORIE_DESC CODE_PARENT  ...  \
# ...

# %% [markdown]
# ❏	Extraire l’information concernant l’année de plantation pour l’ensemble des lignes (rows) et stocker ces informations dans une variable de type List

# %%
df_arbres['ANNEEDEPLANTATION']
# Out:
# 0        1975.0
# 1        1975.0
# 2        2001.0
# 3        1975.0
# 4        2006.0
#           ...
# 31887    2005.0
# 31888    1980.0
# 31889    1980.0
# 31890    1980.0
# 31891    2005.0
# Name: ANNEEDEPLANTATION, Length: 31892, dtype: float64

# %% [markdown]
# Pour combien d’arbres manque-t-il l’information concernant la date de plantation ?

# %%
df_arbres['ANNEEDEPLANTATION'].isna().sum()
# Out:
# 763

# %%
df_arbres['ANNEEDEPLANTATION'].isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 31887    False
# 31888    False
# 31889    False
# 31890    False
# 31891    False
# Name: ANNEEDEPLANTATION, Length: 31892, dtype: bool

# %% [markdown]
# Combien d’arbres sont recensés dans ce jeu de données ?

# %%
# Nombre de lignes dans mon dataframe
nbre_lignes = df_arbres.shape[0]
nbre_lignes
# Out:
# 31892

# %%
# Nombre de valeurs différentes dans mon dataframe (par colonne)
df_arbres.nunique(axis='rows', dropna=True)
# Out:
# ELEM_POINT_ID            31892
# CODE                     31892
# NOM                      31892
# GENRE                        1
# GENRE_DESC                   1
# CATEGORIE                    1
# CATEGORIE_DESC               1
# SOUS_CATEGORIE               4
# SOUS_CATEGORIE_DESC          4
# CODE_PARENT               1462
# CODE_PARENT_DESC          1462
# ADR_SECTEUR                  6
# BIEN_REFERENCE           31892
# GENRE_BOTA                 119
# ESPECE                     274
# VARIETE                    182
# STADEDEDEVELOPPEMENT         3
# EQUIPE                       0
# REMARQUES                   10
# ANNEEDEPLANTATION           62
# RAISONDEPLANTATION           3
# TRAITEMENTCHENILLES          3
# COURRIER                     0
# IDENTIFIANTPLU              46
# TYPEIMPLANTATIONPLU          4
# INTITULEPROTECTIONPLU        3
# ANNEEABATTAGE                0
# ESSOUCHEMENT                 0
# DIAMETREARBRE                0
# CAUSEABATTAGE                0
# ...

# %% [markdown]
# Combien d’arbres ont été plantés en moyenne chaque année

# %%
df_arbres['ANNEEDEPLANTATION'].dropna().value_counts().mean()
# Out:
# 502.0806451612903

# %%
df_arbres.groupby(['ANNEEDEPLANTATION']).size()
# Out:
# ANNEEDEPLANTATION
# 1924.0      12
# 1944.0      27
# 1950.0     409
# 1955.0     118
# 1959.0      16
#           ...
# 2015.0    1028
# 2016.0     518
# 2017.0     638
# 2018.0     778
# 2019.0       7
# Length: 62, dtype: int64

# %% [markdown]
# Combien d’arbres ont été plantés en moyenne chaque année ?

# %%
df_arbres['ANNEEDEPLANTATION'].value_counts().mean()
# Out:
# 502.0806451612903

# %% [markdown]
# Afficher tous les arbres ayant été plantés l’année de votre naissance.
# Combien d’arbres ont été plantés depuis votre naissance ?

# %%
df_arbres['ANNEEDEPLANTATION'].value_counts()[1987]
# Out:
# 755

# %%
df_arbres['ANNEEDEPLANTATION']
# Out:
# 0        1975.0
# 1        1975.0
# 2        2001.0
# 3        1975.0
# 4        2006.0
#           ...
# 31887    2005.0
# 31888    1980.0
# 31889    1980.0
# 31890    1980.0
# 31891    2005.0
# Name: ANNEEDEPLANTATION, Length: 31892, dtype: float64

# %%
df_arbres[df_arbres['ANNEEDEPLANTATION']>1987]
# Out:
#        ELEM_POINT_ID      CODE       NOM GENRE  GENRE_DESC CATEGORIE  \
# 2              23843  ESP17861  ESP17861   VEG  VEGETATION     ESP01
# 4               1778  ESP16403  ESP16403   VEG  VEGETATION     ESP01
# 9               1771  ESP16397  ESP16397   VEG  VEGETATION     ESP01
# 10              1770  ESP16396  ESP16396   VEG  VEGETATION     ESP01
# 13              1737  ESP16378  ESP16378   VEG  VEGETATION     ESP01
# ...              ...       ...       ...   ...         ...       ...
# 31873          13287  ESP20843  ESP20843   VEG  VEGETATION     ESP01
# 31874          24291  ESP20754  ESP20754   VEG  VEGETATION     ESP01
# 31885           9482  ESP19797  ESP19797   VEG  VEGETATION     ESP01
# 31887          16922  ESP19587  ESP19587   VEG  VEGETATION     ESP01
# 31891          24289  ESP14846  ESP14846   VEG  VEGETATION     ESP01
#
#       CATEGORIE_DESC SOUS_CATEGORIE      SOUS_CATEGORIE_DESC CODE_PARENT  ...  \
# ...

# %%
df_arbres[df_arbres['ANNEEDEPLANTATION']>1987]['ANNEEDEPLANTATION'].value_counts().sum()
# Out:
# 14504

# %% [markdown]
# ❏	Pour combien d'arbres manque-t-il l’information concernant le genre botanique ?

# %%
df_arbres[['GENRE_BOTA','ANNEEDEPLANTATION']].isna().sum()
# Out:
# GENRE_BOTA           438
# ANNEEDEPLANTATION    763
# dtype: int64

# %%
df_arbres[["GENRE_BOTA","ANNEEDEPLANTATION"]].value_counts()
# Out:
# GENRE_BOTA  ANNEEDEPLANTATION
# Acer        1975.0               1086
# Platanus    1975.0                615
# Acer        1970.0                422
# Platanus    1950.0                370
#             1976.0                364
#                                  ...
# Ilex        1967.0                  1
# Sophora     2016.0                  1
# Ilex        1924.0                  1
# Hovenia     2014.0                  1
# Poncinos    1960.0                  1
# Length: 1815, dtype: int64

# %% [markdown]
# Tracer l’histogramme représentant le nombre d’arbres plantés par année.

# %%
df_arbres['ANNEEDEPLANTATION'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
df_copy = df_arbres.dropna(subset=['ANNEEDEPLANTATION']).copy()
df_copy.set_index('ANNEEDEPLANTATION', inplace=True)

# %%
df_copy.sort_index()
# Out:
#                    ELEM_POINT_ID      CODE       NOM GENRE  GENRE_DESC  \
# ANNEEDEPLANTATION
# 1924.0                     16012  ESP18024  ESP18024   VEG  VEGETATION
# 1924.0                     12373  ESP20153  ESP20153   VEG  VEGETATION
# 1924.0                     12370  ESP20152  ESP20152   VEG  VEGETATION
# 1924.0                       931  ESP15016  ESP15016   VEG  VEGETATION
# 1924.0                     19650   ESP7574   ESP7574   VEG  VEGETATION
# ...                          ...       ...       ...   ...         ...
# 2019.0                     41383  ESP39336  ESP39336   VEG  VEGETATION
# 2019.0                     41386  ESP39339  ESP39339   VEG  VEGETATION
# 2019.0                     41382  ESP39335  ESP39335   VEG  VEGETATION
# 2019.0                     41381  ESP39334  ESP39334   VEG  VEGETATION
# 2019.0                     36551  ESP37123  ESP37123   VEG  VEGETATION
#
#                   CATEGORIE CATEGORIE_DESC SOUS_CATEGORIE  \
# ANNEEDEPLANTATION
# ...

# %% [markdown]
# Fichier corrompu

# %%
datafile_corr = datapath / "ESP_PUBLIC.IDENTITE_ARBRE_CORRPUTED.csv"
df_arbres_corr = pd.read_csv(datafile_corr,dtype=np.dtype("O"))
df_arbres_init = pd.read_csv(datafile,dtype=np.dtype("O"))

# %%
df = pd.concat([df_arbres_init, df_arbres_corr])
df = df.reset_index(drop=True)

# %%
df_new = df.drop_duplicates(keep=False)

# %%
df_new
# Out:
#       ELEM_POINT_ID      CODE       NOM GENRE  GENRE_DESC CATEGORIE  \
# 158           31975  ESP32701  ESP32701   VEG  VEGETATION     ESP01
# 220           31913  ESP32639  ESP32639   VEG  VEGETATION     ESP01
# 17124          3504   ESP2897   ESP2897   VEG  VEGETATION     ESP01
# 24808           510  ESP14156  ESP14156   VEG  VEGETATION     ESP01
# 29552         13591  ESP21177  ESP21177   VEG  VEGETATION     ESP01
# 29559         17226  ESP25351  ESP25351   VEG  VEGETATION     ESP01
# 32050         31975  ESP32701  ESP32701   VEG  VEGETATION     ESP01
# 32112         31913  ESP32639  ESP32639   VEG  VEGETATION     ESP01
# 49016          3504   ESP2897   ESP2897   VEG  VEGETATION     ESP01
# 56700           510  ESP14156  ESP14156   VEG  VEGETATION     ESP01
# 61444         13591  ESP21177  ESP21177   VEG  VEGETATION     ESP01
# 61451         17226  ESP25351  ESP25351   VEG  VEGETATION     ESP01
#
#       CATEGORIE_DESC SOUS_CATEGORIE      SOUS_CATEGORIE_DESC CODE_PARENT  ...  \
# ...

# %%
df_arbres.columns.intersection(df_arbres_corr.columns)
# Out:
# Index(['ELEM_POINT_ID', 'CODE', 'NOM', 'GENRE', 'GENRE_DESC', 'CATEGORIE',
#        'CATEGORIE_DESC', 'SOUS_CATEGORIE', 'SOUS_CATEGORIE_DESC',
#        'CODE_PARENT', 'CODE_PARENT_DESC', 'ADR_SECTEUR', 'BIEN_REFERENCE',
#        'GENRE_BOTA', 'ESPECE', 'VARIETE', 'STADEDEDEVELOPPEMENT', 'EQUIPE',
#        'REMARQUES', 'ANNEEDEPLANTATION', 'RAISONDEPLANTATION',
#        'TRAITEMENTCHENILLES', 'COURRIER', 'IDENTIFIANTPLU',
#        'TYPEIMPLANTATIONPLU', 'INTITULEPROTECTIONPLU', 'ANNEEABATTAGE',
#        'ESSOUCHEMENT', 'DIAMETREARBRE', 'CAUSEABATTAGE', 'COLLECTIVITE',
#        'GeoJSON'],
#       dtype='object')

# %%
df_arbres.columns.difference(df_arbres_corr.columns)
# Out:
# Index([], dtype='object')

# %%
comparison_df = pd.merge(df_arbres_init, df_arbres_corr, how='inner', on=list(df_arbres_corr.columns))
comparison_df
# Out:
#       ELEM_POINT_ID      CODE       NOM GENRE  GENRE_DESC CATEGORIE  \
# 0             16750  ESP19318  ESP19318   VEG  VEGETATION     ESP01
# 1             20142  ESP18095  ESP18095   VEG  VEGETATION     ESP01
# 2             23843  ESP17861  ESP17861   VEG  VEGETATION     ESP01
# 3             23841  ESP17860  ESP17860   VEG  VEGETATION     ESP01
# 4              1778  ESP16403  ESP16403   VEG  VEGETATION     ESP01
# ...             ...       ...       ...   ...         ...       ...
# 31893         31913  ESP32639  ESP32639   VEG  VEGETATION     ESP01
# 31894          3504   ESP2897   ESP2897   VEG  VEGETATION     ESP01
# 31895           510  ESP14156  ESP14156   VEG  VEGETATION     ESP01
# 31896         13591  ESP21177  ESP21177   VEG  VEGETATION     ESP01
# 31897         17226  ESP25351  ESP25351   VEG  VEGETATION     ESP01
#
#       CATEGORIE_DESC SOUS_CATEGORIE      SOUS_CATEGORIE_DESC CODE_PARENT  ...  \
# ...

# %%
df_arbres_corr[df_arbres_init!=df_arbres_corr] = df_arbres_init[df_arbres_init!=df_arbres_corr]

# %%
df_arbres_init.loc[500:515,'ANNEEDEPLANTATION']
# Out:
# 500    2001
# 501    2001
# 502    2001
# 503    2001
# 504    2001
# 505    2001
# 506    1984
# 507    1984
# 508    1984
# 509    1984
# 510    1984
# 511    1984
# 512    1984
# 513    1984
# 514    1984
# 515    1984
# Name: ANNEEDEPLANTATION, dtype: object

# %% [markdown]
# ## Iteration 2: Questions

# %% [markdown]
# Pour commencer identifiez tous les genres botaniques représentés à Grenoble.
# Combien y en a-t-il ?

# %%
# Nombre de valeurs différentes dans mon dataframe (par colonne)
df_arbres.nunique(axis='rows', dropna=True)
# Out:
# ELEM_POINT_ID            31892
# CODE                     31892
# NOM                      31892
# GENRE                        1
# GENRE_DESC                   1
# CATEGORIE                    1
# CATEGORIE_DESC               1
# SOUS_CATEGORIE               4
# SOUS_CATEGORIE_DESC          4
# CODE_PARENT               1462
# CODE_PARENT_DESC          1462
# ADR_SECTEUR                  6
# BIEN_REFERENCE           31892
# GENRE_BOTA                 119
# ESPECE                     274
# VARIETE                    182
# STADEDEDEVELOPPEMENT         3
# EQUIPE                       0
# REMARQUES                   10
# ANNEEDEPLANTATION           62
# RAISONDEPLANTATION           3
# TRAITEMENTCHENILLES          3
# COURRIER                     0
# IDENTIFIANTPLU              46
# TYPEIMPLANTATIONPLU          4
# INTITULEPROTECTIONPLU        3
# ANNEEABATTAGE                0
# ESSOUCHEMENT                 0
# DIAMETREARBRE                0
# CAUSEABATTAGE                0
# ...

# %% [markdown]
# Identifiez maintenant toutes les espèces différentes présentes à Grenoble

# %%
df_arbres.groupby([ 'GENRE_BOTA', 'ESPECE']).size()
# Out:
# GENRE_BOTA  ESPECE
# Abies       concolor          5
#             koreana           1
#             nordmaniana      20
#             pinsapo           2
# Acer        buergerianum     20
#                            ...
# Ulmus       parvifolia        1
#             pumila            1
#             resista          24
# Zelkova     crenata           2
#             serrata         231
# Length: 312, dtype: int64

# %%
df_genre = df_arbres.groupby([ 'GENRE_BOTA']).size()

# %%
(df_genre*100)/df_genre.sum()
# Out:
# GENRE_BOTA
# Abies            0.082660
# Acacia           0.003179
# Acer            16.722833
# Aesculus         1.468812
# Ailanthus        0.251160
#                   ...
# Thuja            0.149425
# Tilia            5.646341
# Trachycarpus     0.073123
# Ulmus            0.686717
# Zelkova          0.887010
# Length: 119, dtype: float64

# %%
df_esp = df_arbres.groupby([ 'GENRE_BOTA', 'ESPECE']).size()

# %%
(df_esp*100)/df_esp.sum()
# Out:
# GENRE_BOTA  ESPECE
# Abies       alba            0.003366
#             concolor        0.016829
#             koreana         0.003366
#             nordmanniana    0.057220
#             pinsapo         0.006732
#                               ...
# Ulmus       minor           0.457758
#             parvifolia      0.016829
#             resista         0.080781
# Zelkova     crenata         0.006732
#             serrata         0.932346
# Length: 339, dtype: float64

# %% [markdown]
# ## Iteration 3: Questions

# %% [markdown]
# Plusieurs sources évoquent une espérance de vie moyenne des arbres en ville de 30 à 80 ans. Les données de terrain disponibles pour Grenoble corroborent-elles ces sources ?

# %%
df_simple = df_arbres.loc[:, ['ANNEEDEPLANTATION','ANNEEABATTAGE']].copy()

# %%
# Création d'une nouvelle colonne
df_simple['DUREEVIE'] =  df_simple.ANNEEABATTAGE - df_simple.ANNEEDEPLANTATION

# %%
df_simple
# Out:
#        ANNEEDEPLANTATION  ANNEEABATTAGE  DUREEVIE
# 0                    NaN            NaN       NaN
# 1                    NaN            NaN       NaN
# 2                    NaN            NaN       NaN
# 3                    NaN            NaN       NaN
# 4                    NaN            NaN       NaN
# ...                  ...            ...       ...
# 31238             2001.0            NaN       NaN
# 31239             2001.0            NaN       NaN
# 31240             2001.0            NaN       NaN
# 31241             2001.0            NaN       NaN
# 31242             2001.0            NaN       NaN
#
# [31243 rows x 3 columns]
