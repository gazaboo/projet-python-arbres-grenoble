# %%
import numpy as np
import pandas as pd

# %%
# Chargement des données dans un dataframe pandas
df = pd.read_csv('data/arbres.csv')

# %%
def change_name_prefix(df):
    nbre_changement = 50
    for i in range(nbre_changement):
        index = np.random.randint(len(df))
        if type(df.loc[index, 'GENRE_BOTA']) is str:
            df.loc[index, 'GENRE_BOTA'] = ''.join(["Ceci est un : ", df.loc[index, 'GENRE_BOTA']])

def add_unnecessary_space(df):
    nbre_changement = 50
    for i in range(nbre_changement):
        index = np.random.randint(len(df))
        num_space = np.random.randint(5)
        if type(df.loc[index, 'ESPECE']) is str:
            df.loc[index, 'ESPECE'] = ''.join([" "*num_space, df.loc[index, 'ESPECE']])   
            
def change_case(df):
    nbre_changement = 50
    for i in range(nbre_changement):
        index = np.random.randint(len(df))
        if type(df.loc[index, 'GENRE_BOTA']) is str:
            df.loc[index, 'GENRE_BOTA'] = df.loc[index, 'GENRE_BOTA'].upper()

# %%
df = pd.read_csv('data/arbres.csv')
change_name_prefix(df)
add_unnecessary_space(df)
change_case(df)

df.to_csv('data/weird_trees.csv')
# Out:
# 15634
# 24411
# 27709
# 2927
# 17152
# 3481
# 24159
# 21054
# 19259
# 21962
# 28213
# 9185
# 19918
# 5382
# 26853
# 10561
# 7678
# 29902
# 10133
# 29139
# 3120
# 4114
# 15029
# 2896
# 25058
# 7778
# 23224
# 28295
# 3233
# 10479
# 19312
# 19591
# 13327
# 19788
# 17829
# 10448
# 27383
# 22571
# 1031
# 22612
# 5710
# 2428
# 21636
# 10782
# 8778
# 9543
# 4658
# 11740
# 28648
# 11148
# 10446
# 24164
# 13481
# 18375
# 4937
# 27417
# 18591
# 27499
# 7520
# 25285
# 12278
# 17264
# 9794
# 10548
# 21279
# 15374
# 7272
# 5800
# 18152
# 30838
# 9180
# 17628
# 11342
# 56
# 9787
# 2333
# 9643
# 16756
# 1473
# 14303
# 5116
# 14315
# 8078
# 670
# 13193
# 10479
# 26858
# 3052
# 3590
# 10136
# 20247
# 9355
# 22603
# 2028
# 25453
# 18536
# 7709
# 6429
# 13637
# 7193
# 20367
# 1755
# 26988
# 7770
# 5282
# 16903
# 25953
# 22188
# 4356
# 4265
# 70
# 5571
# 23468
# 10122
# 18635
# 894
# 18893
# 10535
# 15282
# 7768
# 7973
# 10619
# 23687
# 7414
# 13470
# 3051
# 17383
# 21011
# 908
# 556
# 19804
# 5061
# ...
